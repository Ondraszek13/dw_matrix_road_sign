# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
import pandas as pd
import numpy as np
import os
import datetime

import tensorflow as tf
from tensorflow.keras.models import  Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

# %load_ext tensorboard

import matplotlib.pyplot as plt
from skimage import color, exposure

from sklearn.metrics import accuracy_score

from hyperopt import hp, STATUS_OK, tpe, Trials, fmin
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
cd '/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_three/dw_matrix_road_sign'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_three/dw_matrix_road_sign

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')

X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim == 1: y_train = to_categorical(y_train)
if y_test.ndim == 1: y_test = to_categorical(y_test)

# %%
input_shape = X_train.shape[1:]
num_class = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
  model.compile(loss='categorical_crossentropy', optimizer='Adam',metrics=['accuracy'])

  logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
  
  model.fit(X_train,
            y_train,
            batch_size=params_fit.get('batch_size', 128),
            epochs=params_fit.get('epochs', 5),
            verbose=params_fit.get('verbose', 1),
            validation_data=params_fit.get('validation_data', (X_train, y_train)),
            callbacks= [tensorboard_callback]
  )
  return model

# %%
def predict(model_trained, X_test, y_test, scoring=accuracy_score):
  y_test_norm = np.argmax( y_test, axis=1)

  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax( y_pred_prob, axis=1)

  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_class):
  return Sequential([            
       Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
       Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
       MaxPool2D(),
       Dropout(0.3),
       
       Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
       MaxPool2D(),
       Dropout(0.3),

       Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
       MaxPool2D(),
       Dropout(0.3),

       Flatten(),

       Dense (1024, activation='relu'),
       Dropout(0.3),

       Dense (1024, activation='relu'),
       Dropout(0.3),

       Dense (num_class, activation='softmax')          
])

#train_and_predict( get_cnn_v5(input_shape, num_class ))

# %%
model = get_cnn_v5(input_shape, num_class)          
model_trained = train_model(model, X_train, y_train)
predict(model_trained, X_test, y_test)
# Out:
# Epoch 1/5
# 272/272 [==============================] - 5s 19ms/step - loss: 2.4441 - accuracy: 0.3054 - val_loss: 0.8356 - val_accuracy: 0.7477
# Epoch 2/5
# 272/272 [==============================] - 5s 18ms/step - loss: 0.6565 - accuracy: 0.7854 - val_loss: 0.2166 - val_accuracy: 0.9317
# Epoch 3/5
# 272/272 [==============================] - 5s 18ms/step - loss: 0.2978 - accuracy: 0.9070 - val_loss: 0.0832 - val_accuracy: 0.9732
# Epoch 4/5
# 272/272 [==============================] - 5s 19ms/step - loss: 0.2024 - accuracy: 0.9370 - val_loss: 0.0561 - val_accuracy: 0.9840
# Epoch 5/5
# 272/272 [==============================] - 5s 19ms/step - loss: 0.1395 - accuracy: 0.9598 - val_loss: 0.0271 - val_accuracy: 0.9913
# 0.9702947845804989

# %%
def get_model(params):
  return Sequential([            
       Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
       Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),

       MaxPool2D(),
       Dropout(params['dropout_cnn_block_one']),
       
       Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
       MaxPool2D(),
       Dropout(params['dropout_cnn_block_two']),

       Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
       Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
       MaxPool2D(),
       Dropout(params['dropout_cnn_block_three']),

       Flatten(),

       Dense (1024, activation='relu'),
       Dropout(params['dropout_dense_block_one']),

       Dense (1024, activation='relu'),
       Dropout(params['dropout_dense_block_two']),

       Dense (num_class, activation='softmax')          
])

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam',metrics=['accuracy'])
 
  model.fit(X_train,
            y_train,
            batch_size=int(params.get('batch_size', 128)),
            epochs=5,
            verbose=0,
            
      )
  score = model.evaluate(X_test, y_test, verbose=0)
  accuracy = score[1]
  print(params, 'accuracy={}'.format(accuracy))

  return {'loss': -accuracy, 'status': STATUS_OK, 'model':model}      #dzięki temu możemy minimalizować tę funkcję w celu uzyskania jak najlepszego acc

# %%
space = {
    'batch size': hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_three': hp.uniform('dropout_cnn_block_three', 0.3, 0.5),
    
    'dropout_dense_block_one': hp.uniform('dropout_dense_block_one', 0.3, 0.7),
    'dropout_dense_block_two': hp.uniform('dropout_dense_block_two', 0.3, 0.7),
}

best = fmin(
    func_obj,
    space,
    tpe.suggest,
    30,
    Trials()
)
# Out:
# {'batch size': 170.0, 'dropout_cnn_block_one': 0.3493820452203551, 'dropout_cnn_block_three': 0.34331326217307706, 'dropout_cnn_block_two': 0.4826926687987796, 'dropout_dense_block_one': 0.3317574630213485, 'dropout_dense_block_two': 0.48241596307372414}
# accuracy=0.9671201705932617
# {'batch size': 160.0, 'dropout_cnn_block_one': 0.3984749454199255, 'dropout_cnn_block_three': 0.4867482927416164, 'dropout_cnn_block_two': 0.36865783877306907, 'dropout_dense_block_one': 0.6214293952128941, 'dropout_dense_block_two': 0.5287828893165061}
# accuracy=0.9405895471572876
# {'batch size': 100.0, 'dropout_cnn_block_one': 0.3900018006321846, 'dropout_cnn_block_three': 0.48700120983092227, 'dropout_cnn_block_two': 0.3174155363165632, 'dropout_dense_block_one': 0.3449676360846327, 'dropout_dense_block_two': 0.5344677992224336}
# accuracy=0.9616780281066895
# {'batch size': 120.0, 'dropout_cnn_block_one': 0.3924452283859202, 'dropout_cnn_block_three': 0.4993156693443664, 'dropout_cnn_block_two': 0.3369946265150307, 'dropout_dense_block_one': 0.3458484758112832, 'dropout_dense_block_two': 0.5881590484506224}
# accuracy=0.9283446669578552
# {'batch size': 150.0, 'dropout_cnn_block_one': 0.43230781639876514, 'dropout_cnn_block_three': 0.46742424502892743, 'dropout_cnn_block_two': 0.37365283848211256, 'dropout_dense_block_one': 0.3135029270235118, 'dropout_dense_block_two': 0.3620423157780971}
# accuracy=0.9571428298950195
# {'batch size': 170.0, 'dropout_cnn_block_one': 0.4085072452235176, 'dropout_cnn_block_three': 0.4014655289445685, 'dropout_cnn_block_two': 0.36332878795790724, 'dropout_dense_block_one': 0.5951100645217651, 'dropout_dense_block_two': 0.37512010480311936}
# accuracy=0.9664399027824402
# {'batch size': 170.0, 'dropout_cnn_block_one': 0.3684483791184168, 'dropout_cnn_block_three': 0.38098689302693556, 'dropout_cnn_block_two': 0.4879237561987225, 'dropout_dense_block_one': 0.48828769971632796, 'dropout_dense_block_two': 0.42081179506603567}
# accuracy=0.958276629447937
# {'batch size': 200.0, 'dropout_cnn_block_one': 0.3977481034609497, 'dropout_cnn_block_three': 0.32411884831361676, 'dropout_cnn_block_two': 0.31986973812759445, 'dropout_dense_block_one': 0.45721540488203305, 'dropout_dense_block_two': 0.3320701619808248}
# accuracy=0.9718821048736572
# {'batch size': 130.0, 'dropout_cnn_block_one': 0.47894876052270746, 'dropout_cnn_block_three': 0.43133600956392393, 'dropout_cnn_block_two': 0.3584349632586421, 'dropout_dense_block_one': 0.6999085607256847, 'dropout_dense_block_two': 0.44971232704058456}
# accuracy=0.9541950225830078
# {'batch size': 140.0, 'dropout_cnn_block_one': 0.3633650503775611, 'dropout_cnn_block_three': 0.3449408310351731, 'dropout_cnn_block_two': 0.431496213036167, 'dropout_dense_block_one': 0.6187565439595326, 'dropout_dense_block_two': 0.35247691164735284}
# accuracy=0.9546485543251038
# {'batch size': 170.0, 'dropout_cnn_block_one': 0.3578178802602749, 'dropout_cnn_block_three': 0.4301638052501036, 'dropout_cnn_block_two': 0.35590628942911, 'dropout_dense_block_one': 0.5738852439946649, 'dropout_dense_block_two': 0.6827251503023855}
# accuracy=0.9632652997970581
# {'batch size': 150.0, 'dropout_cnn_block_one': 0.32536201841791423, 'dropout_cnn_block_three': 0.3890278166293001, 'dropout_cnn_block_two': 0.45400062426228843, 'dropout_dense_block_one': 0.42386864357824355, 'dropout_dense_block_two': 0.4604725327449793}
# accuracy=0.9716553092002869
# {'batch size': 120.0, 'dropout_cnn_block_one': 0.4232765899815359, 'dropout_cnn_block_three': 0.4466861744311289, 'dropout_cnn_block_two': 0.40280710053874813, 'dropout_dense_block_one': 0.30832712562358433, 'dropout_dense_block_two': 0.330274639919228}
# accuracy=0.9560090899467468
# {'batch size': 160.0, 'dropout_cnn_block_one': 0.4220524993823184, 'dropout_cnn_block_three': 0.30695386199674624, 'dropout_cnn_block_two': 0.4447662980091217, 'dropout_dense_block_one': 0.30742524547922234, 'dropout_dense_block_two': 0.37252322555532835}
# accuracy=0.9614512324333191
# {'batch size': 150.0, 'dropout_cnn_block_one': 0.42258844806474327, 'dropout_cnn_block_three': 0.37285348186026296, 'dropout_cnn_block_two': 0.4204193377567441, 'dropout_dense_block_one': 0.3878911836634655, 'dropout_dense_block_two': 0.5001333348364729}
# accuracy=0.9387755393981934
# {'batch size': 120.0, 'dropout_cnn_block_one': 0.3113786429711421, 'dropout_cnn_block_three': 0.4470522802569047, 'dropout_cnn_block_two': 0.33162684718164154, 'dropout_dense_block_one': 0.5441929625412272, 'dropout_dense_block_two': 0.6793385197331666}
# accuracy=0.9657596349716187
# {'batch size': 180.0, 'dropout_cnn_block_one': 0.45951780301736433, 'dropout_cnn_block_three': 0.4141210213246641, 'dropout_cnn_block_two': 0.36855728539170785, 'dropout_dense_block_one': 0.5787932997114333, 'dropout_dense_block_two': 0.6888663191078538}
# accuracy=0.9344671368598938
# {'batch size': 130.0, 'dropout_cnn_block_one': 0.3185247705534174, 'dropout_cnn_block_three': 0.4989506274893233, 'dropout_cnn_block_two': 0.3130723596299971, 'dropout_dense_block_one': 0.6872749124728171, 'dropout_dense_block_two': 0.5051628838260762}
# accuracy=0.9712018370628357
# {'batch size': 180.0, 'dropout_cnn_block_one': 0.3857497993901381, 'dropout_cnn_block_three': 0.4883617575281468, 'dropout_cnn_block_two': 0.42808681923293657, 'dropout_dense_block_one': 0.6130353435267071, 'dropout_dense_block_two': 0.5587354890080336}
# accuracy=0.9310657382011414
# {'batch size': 170.0, 'dropout_cnn_block_one': 0.4172980179037794, 'dropout_cnn_block_three': 0.4550440491398817, 'dropout_cnn_block_two': 0.4654550142966789, 'dropout_dense_block_one': 0.6021142384477123, 'dropout_dense_block_two': 0.3211505303672536}
# accuracy=0.9090703129768372
# {'batch size': 190.0, 'dropout_cnn_block_one': 0.33807939898966133, 'dropout_cnn_block_three': 0.3079310783297187, 'dropout_cnn_block_two': 0.4639348007289732, 'dropout_dense_block_one': 0.43512063133820433, 'dropout_dense_block_two': 0.6087210180486524}
# accuracy=0.9471655488014221
# {'batch size': 200.0, 'dropout_cnn_block_one': 0.3008072210481057, 'dropout_cnn_block_three': 0.3405537435424122, 'dropout_cnn_block_two': 0.39422092371830336, 'dropout_dense_block_one': 0.4662819579301064, 'dropout_dense_block_two': 0.4229485103019552}
# accuracy=0.9594104290008545
# {'batch size': 100.0, 'dropout_cnn_block_one': 0.49645567947970604, 'dropout_cnn_block_three': 0.32548332667222724, 'dropout_cnn_block_two': 0.45828784055465505, 'dropout_dense_block_one': 0.41820003663118865, 'dropout_dense_block_two': 0.4166057797973454}
# accuracy=0.9666666388511658
# {'batch size': 200.0, 'dropout_cnn_block_one': 0.4520060120916316, 'dropout_cnn_block_three': 0.3716794268257571, 'dropout_cnn_block_two': 0.3954752834580677, 'dropout_dense_block_one': 0.5275640309936109, 'dropout_dense_block_two': 0.30199011994958}
# accuracy=0.9480725526809692
# {'batch size': 190.0, 'dropout_cnn_block_one': 0.3289611467634636, 'dropout_cnn_block_three': 0.3602044557781421, 'dropout_cnn_block_two': 0.3034620329725406, 'dropout_dense_block_one': 0.4042175696847403, 'dropout_dense_block_two': 0.6277131121952386}
# accuracy=0.9691609740257263
# {'batch size': 110.0, 'dropout_cnn_block_one': 0.37789456846017033, 'dropout_cnn_block_three': 0.39160474566248293, 'dropout_cnn_block_two': 0.4931125448293574, 'dropout_dense_block_one': 0.45317942547388834, 'dropout_dense_block_two': 0.4666842420626176}
# accuracy=0.9301587343215942
# {'batch size': 140.0, 'dropout_cnn_block_one': 0.34000353308265596, 'dropout_cnn_block_three': 0.3230144203898337, 'dropout_cnn_block_two': 0.4117813619371241, 'dropout_dense_block_one': 0.3753655270857519, 'dropout_dense_block_two': 0.3976907404249805}
# accuracy=0.9664399027824402
# {'batch size': 190.0, 'dropout_cnn_block_one': 0.44338008343293583, 'dropout_cnn_block_three': 0.4087433394471223, 'dropout_cnn_block_two': 0.44561155993519996, 'dropout_dense_block_one': 0.5133063406719871, 'dropout_dense_block_two': 0.30631070858650056}
# accuracy=0.9718821048736572
# {'batch size': 190.0, 'dropout_cnn_block_one': 0.4408355782320517, 'dropout_cnn_block_three': 0.41250904814436296, 'dropout_cnn_block_two': 0.4762630002125705, 'dropout_dense_block_one': 0.5100738708534526, 'dropout_dense_block_two': 0.30550724176488653}
# accuracy=0.960544228553772
# {'batch size': 200.0, 'dropout_cnn_block_one': 0.47502110119117114, 'dropout_cnn_block_three': 0.35356913137565515, 'dropout_cnn_block_two': 0.3846863592507498, 'dropout_dense_block_one': 0.6540984755382395, 'dropout_dense_block_two': 0.3349948129689717}
# accuracy=0.9519274234771729
# 100%|██████████| 30/30 [07:49<00:00, 15.66s/it, best loss: -0.9718821048736572]
